-- %%
SELECT
    segmento_rfm,

    quantidade_clientes,
    participacao_clientes_percentual,

    faturamento,
    participacao_faturamento_percentual,

    lucro_bruto,
    margem_percentual,

    recencia_media_dias,
    frequencia_media,

    ticket_medio,
    valor_medio_cliente

FROM resumo_segmentos_rfm

ORDER BY faturamento DESC;
