-- %%
SELECT
    data_referencia,

    total_receber_aberto,
    total_a_vencer,
    total_receber_vencido,

    taxa_inadimplencia_percentual,
    prazo_medio_recebimento_dias,

    total_pagar_aberto,
    total_pagar_vencido,

    entradas_previstas_30d,
    saidas_previstas_30d,
    saldo_previsto_30d

FROM resumo_financeiro_atual;
