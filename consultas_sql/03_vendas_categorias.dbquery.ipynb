-- %%
SELECT
    mes_referencia,
    categoria,

    faturamento,
    lucro_bruto,
    margem_percentual,

    quantidade_vendida,
    quantidade_pedidos,

    clientes_ativos,
    produtos_vendidos

FROM vendas_categoria_mensal

ORDER BY
    mes_referencia,
    faturamento DESC;
