-- %%
SELECT
    'vendas_mensais' AS tabela,
    COUNT(*) AS registros
FROM vendas_mensais

UNION ALL

SELECT
    'clientes_rfm',
    COUNT(*)
FROM clientes_rfm

UNION ALL

SELECT
    'produtos_curva_abc',
    COUNT(*)
FROM produtos_curva_abc

UNION ALL

SELECT
    'analise_estoque_atual',
    COUNT(*)
FROM analise_estoque_atual

UNION ALL

SELECT
    'sugestao_compras',
    COUNT(*)
FROM sugestao_compras

UNION ALL

SELECT
    'inadimplencia_clientes',
    COUNT(*)
FROM inadimplencia_clientes;
